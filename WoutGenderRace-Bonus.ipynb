# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn import preprocessing, feature_selection
# %matplotlib inline
from IPython.display import Markdown, display

# %%
# Reading datasets

levels_df = pd.read_csv('https://raw.github.ccs.neu.edu/pantu16/cs6620_peiling_yuting_pedro/main/data/levels_fyi_salary_data.csv?token=AAABOLP6YVPNZECODFFF723CMZ6XM')

# %%
levels_df.dtypes
# Out:
# timestamp                   object
# company                     object
# level                       object
# title                       object
# totalyearlycompensation      int64
# location                    object
# yearsofexperience          float64
# yearsatcompany             float64
# tag                         object
# basesalary                 float64
# stockgrantvalue            float64
# bonus                      float64
# gender                      object
# otherdetails                object
# cityid                       int64
# dmaid                      float64
# rowNumber                    int64
# Masters_Degree               int64
# Bachelors_Degree             int64
# Doctorate_Degree             int64
# Highschool                   int64
# Some_College                 int64
# Race_Asian                   int64
# Race_White                   int64
# Race_Two_Or_More             int64
# Race_Black                   int64
# Race_Hispanic                int64
# Race                        object
# Education                   object
# dtype: object

# %%
# Count of NaNs
levels_df.isna().sum()
# Out:
# timestamp                      0
# company                        5
# level                        119
# title                          0
# totalyearlycompensation        0
# location                       0
# yearsofexperience              0
# yearsatcompany                 0
# tag                          854
# basesalary                     0
# stockgrantvalue                0
# bonus                          0
# gender                     19540
# otherdetails               22505
# cityid                         0
# dmaid                          2
# rowNumber                      0
# Masters_Degree                 0
# Bachelors_Degree               0
# Doctorate_Degree               0
# Highschool                     0
# Some_College                   0
# Race_Asian                     0
# Race_White                     0
# Race_Two_Or_More               0
# Race_Black                     0
# Race_Hispanic                  0
# Race                       40215
# Education                  32272
# dtype: int64

# %%
# 'Company': Drop NaN values since there is no way to infer company
levels_df.dropna(subset = ['company'], inplace=True)

# Refactor Companies' names to avoid duplication with misspelled names
# Reducing unique companies' names from 1631 to 1100
levels_df['std_company_name'] = levels_df['company'].map(lambda x: x.strip().lower().replace(" ", "_"))

# Replace NaN values in categorical features with "Unknown" to avoid dropping rows
features_to_replace = {'level': np.nan,
                   'tag': np.nan,
                    'gender': np.nan,
                    'otherdetails': np.nan,
                    'Race': np.nan,
                   'Education': np.nan}

replacement_values = {'level': 'Unknown_level',
                   'tag': 'Unknown_tag',
                    'gender': 'Unknown_gender',
                    'otherdetails': 'No_details',
                    'Race': 'Unknown_race',
                   'Education': 'Unknown_degree'}

levels_df.replace(to_replace=features_to_replace,
                  value=replacement_values,
                  inplace=True)

# 'dmid' replace NA values with 0
levels_df['dmaid'].fillna(0, inplace=True)

# 'gender' rename random value
levels_df['gender'] = levels_df['gender'].replace('Title: Senior Software Engineer','Unknown_gender')
levels_df['gender'] = levels_df['gender'].replace('Other','Other_gender')

# 'Race' rename
levels_df['Race'] = levels_df['Race'].replace('Two Or More','Two_Or_More_race')

# Count of NaNs
levels_df.isna().sum()
# Out:
# timestamp                  0
# company                    0
# level                      0
# title                      0
# totalyearlycompensation    0
# location                   0
# yearsofexperience          0
# yearsatcompany             0
# tag                        0
# basesalary                 0
# stockgrantvalue            0
# bonus                      0
# gender                     0
# otherdetails               0
# cityid                     0
# dmaid                      0
# rowNumber                  0
# Masters_Degree             0
# Bachelors_Degree           0
# Doctorate_Degree           0
# Highschool                 0
# Some_College               0
# Race_Asian                 0
# Race_White                 0
# Race_Two_Or_More           0
# Race_Black                 0
# Race_Hispanic              0
# Race                       0
# Education                  0
# std_company_name           0
# dtype: int64

# %%
# # replace 0.0 with 'nan' so mean() ignore 0.0 values
# features_to_replace = {'bonus': 0.0}

# replacement_values = {'bonus': np.nan}

# levels_df.replace(to_replace=features_to_replace,
#                   value=replacement_values,
#                   inplace=True)

# 'bonus' replace 0.0 values with median basesalary for years of experience
bonus_dict = levels_df.groupby('yearsofexperience')['bonus'].median().to_dict()

# check for np.nan in bonus column and use yearsofexperience to choose bonus from base_salary_dict
levels_df.loc[levels_df['bonus'] == 0, 'bonus'] = [bonus_dict[x] for x in levels_df.loc[levels_df['bonus'] == 0, 'yearsofexperience']]

zero_bonus = levels_df[levels_df['bonus'] == 0]
zero_bonus
# Out:
#                  timestamp    company                     level  \
# 120      1/4/2018 18:16:53  Microsoft                        61
# 157      2/8/2018 10:20:13    Netflix  Senior Software Engineer
# 193     2/27/2018 13:57:26     Amazon                        L5
# 399      5/31/2018 8:50:38    Zendesk         Software engineer
# 414      6/5/2018 12:54:59     Amazon                        L5
# 594      7/14/2018 9:33:16    Shopify                        E3
# 633     7/23/2018 21:14:20     Square                        L5
# 9515     8/9/2019 10:10:46     Amazon                        L6
# 9615    8/13/2019 10:27:16     Amazon                        L6
# 31953    10/6/2020 8:58:43     Amazon                        L6
# 32644  10/13/2020 14:22:39        IBM                    Band 7
# 39957   1/21/2021 16:01:32        IBM                    Band 9
# 46988    4/3/2021 11:04:46     Disney                         5
# 62150   9/12/2019 22:22:47     Amazon                        L4
#
#                    title  totalyearlycompensation              location  \
# 120    Software Engineer                   150000           Redmond, WA
# 157    Software Engineer                   567000         Los Gatos, CA
# 193    Software Engineer                   191000           Seattle, WA
# 399    Software Engineer                   166000     San Francisco, CA
# 414    Software Engineer                   240000           Seattle, WA
# 594    Software Engineer                   120000  Waterloo, ON, Canada
# 633    Software Engineer                   250000     San Francisco, CA
# 9515   Software Engineer                   356000           Seattle, WA
# 9615   Software Engineer                   356000           Seattle, WA
# 31953  Software Engineer                   415000           Seattle, WA
# 32644  Software Engineer                   107000          New York, NY
# 39957   Business Analyst                   155000          San Jose, CA
# 46988   Product Designer                   102000             Crapo, MD
# 62150  Software Engineer                   144000           Seattle, WA
#
#        yearsofexperience  yearsatcompany                             tag  \
# 120                  3.5             3.0                     Unknown_tag
# 157                  5.5             3.5                     Unknown_tag
# 193                  3.8             3.8                     Unknown_tag
# 399                  3.8             0.1                     Unknown_tag
# 414                  5.5             5.5  Distributed Systems (Back-End)
# 594                  3.5             0.5                      Full Stack
# 633                  3.5             0.0                     Unknown_tag
# 9515                42.0             4.0      API Development (Back-End)
# 9615                42.0             4.0  Distributed Systems (Back-End)
# 31953               36.0            15.0  Distributed Systems (Back-End)
# 32644               36.0             9.0                    Applications
# 39957               45.0            20.0                        Internal
# 46988               69.0            69.0              Interaction Design
# 62150                0.6             0.0                         ML / AI
#
#        basesalary  stockgrantvalue  bonus          gender  \
# 120           0.0              0.0    0.0  Unknown_gender
# 157      540000.0          27000.0    0.0  Unknown_gender
# 193      134500.0          56000.0    0.0  Unknown_gender
# 399      130000.0          36000.0    0.0            Male
# 414      130000.0         110000.0    0.0            Male
# 594       95000.0          25000.0    0.0            Male
# 633      170000.0          80000.0    0.0  Unknown_gender
# 9515     160000.0         196000.0    0.0            Male
# 9615     160000.0         196000.0    0.0            Male
# 31953    160000.0         255000.0    0.0            Male
# 32644    107000.0              0.0    0.0            Male
# 39957    155000.0              0.0    0.0          Female
# 46988    100000.0           2000.0    0.0  Unknown_gender
# 62150    108000.0          17500.0    0.0            Male
#
#                                                                  otherdetails  \
# 120                                                                No_details
# 157                                 Stock is options at 40% of strike monthly
# 193                                                                No_details
# 399                                                                No_details
# 414                                                                No_details
# 594                                                                No_details
# 633                                                                No_details
# 9515                                                               No_details
# 9615                                                               No_details
# 31953                          Race: White, Academic Level: Bachelor’s degree
# 32644  Title: Software Engineer, Race: White, Academic Level: Master’s degree
# 39957                    Remote, Race: White, Academic Level: Master’s degree
# 46988                                                         Title: Joiooooo
# 62150                                                              No_details
#
#        cityid  dmaid  rowNumber  Masters_Degree  Bachelors_Degree  \
# 120     11521  819.0        207               0                 0
# 157      7277  807.0        288               0                 0
# 193     11527  819.0        341               0                 0
# 399      7419  807.0        765               0                 0
# 414     11527  819.0        807               0                 0
# 594      3488    0.0       1117               0                 0
# 633      7419  807.0       1190               0                 0
# 9515    11527  819.0      12936               0                 0
# 9615    11527  819.0      13064               0                 0
# 31953   11527  819.0      44076               0                 1
# 32644   10182  501.0      45005               1                 0
# 39957    7422  807.0      54897               1                 0
# 46988   23596  512.0      64028               0                 0
# 62150   11527  819.0      14504               0                 0
#
#        Doctorate_Degree  Highschool  Some_College  Race_Asian  Race_White  \
# 120                   0           0             0           0           0
# 157                   0           0             0           0           0
# 193                   0           0             0           0           0
# 399                   0           0             0           0           0
# 414                   0           0             0           0           0
# 594                   0           0             0           0           0
# 633                   0           0             0           0           0
# 9515                  0           0             0           0           0
# 9615                  0           0             0           0           0
# 31953                 0           0             0           0           1
# 32644                 0           0             0           0           1
# 39957                 0           0             0           0           1
# 46988                 0           0             0           0           0
# 62150                 0           0             0           0           0
#
#        Race_Two_Or_More  Race_Black  Race_Hispanic          Race  \
# 120                   0           0              0  Unknown_race
# 157                   0           0              0  Unknown_race
# 193                   0           0              0  Unknown_race
# 399                   0           0              0  Unknown_race
# 414                   0           0              0  Unknown_race
# 594                   0           0              0  Unknown_race
# 633                   0           0              0  Unknown_race
# 9515                  0           0              0  Unknown_race
# 9615                  0           0              0  Unknown_race
# 31953                 0           0              0         White
# 32644                 0           0              0         White
# 39957                 0           0              0         White
# 46988                 0           0              0  Unknown_race
# 62150                 0           0              0  Unknown_race
#
#                Education std_company_name
# 120       Unknown_degree        microsoft
# 157       Unknown_degree          netflix
# 193       Unknown_degree           amazon
# 399       Unknown_degree          zendesk
# 414       Unknown_degree           amazon
# 594       Unknown_degree          shopify
# 633       Unknown_degree           square
# 9515      Unknown_degree           amazon
# 9615      Unknown_degree           amazon
# 31953  Bachelor's Degree           amazon
# 32644    Master's Degree              ibm
# 39957    Master's Degree              ibm
# 46988     Unknown_degree           disney
# 62150     Unknown_degree           amazon

# %%
# # Drop instances with 0 bonus

levels_df.drop(levels_df[levels_df['bonus'] == 0].index, inplace = True)

# %%
# Converting timestamp to datetime64

levels_df['timestamp'] = pd.to_datetime(levels_df['timestamp'])
levels_df.dtypes
# Out:
# timestamp                  datetime64[ns]
# company                            object
# level                              object
# title                              object
# totalyearlycompensation             int64
# location                           object
# yearsofexperience                 float64
# yearsatcompany                    float64
# tag                                object
# basesalary                        float64
# stockgrantvalue                   float64
# bonus                             float64
# gender                             object
# otherdetails                       object
# cityid                              int64
# dmaid                             float64
# rowNumber                           int64
# Masters_Degree                      int64
# Bachelors_Degree                    int64
# Doctorate_Degree                    int64
# Highschool                          int64
# Some_College                        int64
# Race_Asian                          int64
# Race_White                          int64
# Race_Two_Or_More                    int64
# Race_Black                          int64
# Race_Hispanic                       int64
# Race                               object
# Education                          object
# std_company_name                   object
# dtype: object

# %% [markdown]
# ### Feature Selection

# %%
# Correlation Matrix

plt.figure(figsize=(12,8))
sns.heatmap(levels_df.corr(), cmap="RdBu")
plt.title("Correlations Matrix", size=17)
plt.show()

# %%
# Mutual Information with standardized numeric features and bonus as target variable

# Select numeric features, drop bonus
numeric_features_df = levels_df.select_dtypes(include=np.number).copy()
# Drop totalyearlycompensation, bonu, stockgrantvalue since prediction will be made for bonus
numeric_features_df.drop(labels=['basesalary', 'totalyearlycompensation', 'bonus', 'stockgrantvalue'], axis=1, inplace=True)
numeric_features_names = numeric_features_df.columns.tolist()

# Standardize
numeric_features_std = preprocessing.scale(numeric_features_df)

# Create a dataframe from ndnumpy array
numeric_std_df = pd.DataFrame(numeric_features_std, columns=numeric_features_names)

y_vector = levels_df['bonus']
mutual_info_array = feature_selection.mutual_info_regression(X=numeric_std_df, y = y_vector)
mutual_info_array

# Building a dataframe with index = feature's name and column = 'MutualInfo'
mutual_info_df = pd.DataFrame(mutual_info_array, columns=['MutualInfo'], index=numeric_features_names)
mutual_info_df.sort_values(by='MutualInfo', ascending=False, inplace=True)
mutual_info_df
# Out:
#                    MutualInfo
# cityid               0.177434
# dmaid                0.117917
# yearsofexperience    0.098647
# yearsatcompany       0.031786
# rowNumber            0.022801
# Bachelors_Degree     0.013833
# Doctorate_Degree     0.009096
# Race_White           0.008261
# Some_College         0.003950
# Masters_Degree       0.003347
# Race_Asian           0.003314
# Race_Black           0.001539
# Highschool           0.000000
# Race_Two_Or_More     0.000000
# Race_Hispanic        0.000000

# %%
# Encode Location, Since cityid is a relevant feature

# OPTION 0: hot encoding and use all columns
# levels_df = levels_df.join(pd.get_dummies(levels_df.location))

# OPTION 1: Binary Encoding for location

# Requires to install category_encoders run: pip install category_encoders
# Using Binary Encoding Reference: https://www.analyticsvidhya.com/blog/2020/08/types-of-categorical-data-encoding/
# https://contrib.scikit-learn.org/category_encoders/index.html

# import category_encoders as ce

# binary_encoder = ce.BinaryEncoder(cols=['location'], return_df=True)
# levels_df = binary_encoder.fit_transform(levels_df)
# levels_df.drop(['cityid'], axis=1, inplace=True)

# levels_df.head(10)

# %%
# # Encode Location

# # OPTION 2: One hot encoding TOP X most frequent locations 
# location_threshold = 1000 # locations with more than 1000 instances
# top_locations = levels_df[levels_df['location'].isin(levels_df['location'].value_counts()[levels_df['location'].value_counts() > location_threshold].index)].location.unique()
# top_locations = top_locations.tolist()

# # Join locations
# levels_df = levels_df.join(pd.get_dummies(levels_df.location)[top_locations])
# levels_df.head()

# # Optional
# levels_df.drop(['cityid', 'location'], axis=1, inplace=True)

# %%
# # Encode Location

# OPTION 3: One hot encoding splitting by countries and cities in the US and selecting TOP X most frequent locations

# Encode location for different countries and for cities in the US
levels_df['country'] = levels_df.location.str.split(pat=',').apply(lambda x:x[-1][1:])
levels_df.loc[levels_df.country.str.len() == 2,'country'] = 'US'

# Encode Countries: Find countries with more than X instances
# TODO: decide which countries we want to keep
country_threshold = 1000 # countries with more than 1000 instances
top_countries = levels_df[levels_df['country'].isin(levels_df['country'].value_counts()[levels_df['country'].value_counts() > country_threshold].index)].country.unique()
top_countries = top_countries.tolist()

# Join countries
levels_df = levels_df.join(pd.get_dummies(levels_df.country)[top_countries])

# Encode US cities: Find cities with more than X instances 
# TODO: decide which US cities we want to keep
city_threshold = 1000 # cities with more than 1000 instances
top_us_cities = levels_df[levels_df['location'].isin(levels_df[levels_df['US']==1]['location'].value_counts()[levels_df[levels_df['US']==1]['location'].value_counts() > city_threshold].index)].location.unique()
top_us_cities = top_us_cities.tolist()

# Join US cities
levels_df = levels_df.join(pd.get_dummies(levels_df.location)[top_us_cities])

# Optional
levels_df.drop(['cityid', 'location', 'country'], axis=1, inplace=True)

# %%
# Encode Race
levels_df.drop(labels=['Race_Asian', 'Race_White', 'Race_Two_Or_More', 'Race_Black', 'Race_Hispanic'], axis=1, inplace=True)
#levels_df = levels_df.join(pd.get_dummies(levels_df.Race))

# Encode Gender
#levels_df = levels_df.join(pd.get_dummies(levels_df.gender))

# Optional
levels_df.drop(['Race', 'gender'], axis=1, inplace=True)

# %%
# Encode Title
stem_titles = ['Product Manager','Software Engineer',
'Software Engineering Manager',
 'Data Scientist',
 'Solution Architect',
 'Technical Program Manager',
 'Hardware Engineer',
 'Mechanical Engineer']

# TODO: choose only Stem_titles or ALL titles

levels_df = levels_df.join(pd.get_dummies(levels_df.title)[stem_titles])
# levels_df = levels_df.join(pd.get_dummies(levels_df.title))

# Optional
levels_df.drop(['title'], axis=1, inplace=True)

# %%
# Encode Education
levels_df.drop(labels=['Masters_Degree', 'Bachelors_Degree', 'Doctorate_Degree', 'Highschool', 'Some_College'], axis=1, inplace=True)

# OPTION 0: hot encoding and use all columns

# OPTION 1: Ordinal Encoding
education_scale_map = {"Unknown_degree":0, "Highschool":1, "Some College":2, "Bachelor's Degree":3, "Master's Degree":4, "PhD":5}
levels_df['Education'] = levels_df['Education'].replace(education_scale_map)

# OPTION 2: Hot encoding
# levels_df = levels_df.join(pd.get_dummies(levels_df.Education))
# levels_df.drop(['Education'], axis=1, inplace=True)

# %%
# Top Companies

# Changing options to display full result
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.set_option('display.max_colwidth', None)

# Print np arrays without truncation
np.set_printoptions(threshold=np.inf)

# 2 decimals for operations in pandas
pd.set_option('precision', 2)

levels_df['std_company_name'].value_counts()
# Out:
# amazon                                     8193
# microsoft                                  5240
# google                                     4363
# facebook                                   3004
# apple                                      2047
# oracle                                     1143
# salesforce                                 1065
# intel                                       966
# ibm                                         925
# cisco                                       923
# uber                                        893
# capital_one                                 786
# linkedin                                    750
# vmware                                      682
# qualcomm                                    573
# jpmorgan_chase                              542
# bloomberg                                   537
# goldman_sachs                               475
# paypal                                      451
# intuit                                      450
# nvidia                                      405
# deloitte                                    402
# twitter                                     398
# walmart_labs                                386
# adobe                                       385
# ebay                                        366
# accenture                                   355
# expedia                                     352
# sap                                         339
# wayfair                                     339
# lyft                                        326
# netflix                                     267
# workday                                     264
# dropbox                                     254
# shopify                                     233
# airbnb                                      232
# dell_technologies                           228
# visa                                        221
# atlassian                                   220
# snap                                        198
# yelp                                        196
# servicenow                                  189
# yahoo                                       189
# tesla                                       179
# square                                      175
# stripe                                      173
# indeed                                      172
# yandex                                      170
# bytedance                                   169
# splunk                                      161
# zillow                                      161
# comcast                                     149
# broadcom                                    144
# t-mobile                                    142
# spotify                                     141
# nutanix                                     138
# pinterest                                   137
# epam_systems                                135
# general_motors                              134
# american_express                            134
# autodesk                                    132
# godaddy                                     130
# boeing                                      129
# walmart                                     129
# morgan_stanley                              129
# doordash                                    127
# samsung                                     126
# lockheed_martin                             125
# amd                                         123
# ernst_and_young                             122
# qualtrics                                   118
# cruise                                      117
# booking.com                                 117
# instacart                                   117
# twilio                                      116
# box                                         111
# northrop_grumman                            107
# pwc                                         103
# arm                                         100
# coinbase                                     98
# citi                                         97
# flipkart                                     96
# disney                                       96
# cerner                                       96
# usaa                                         94
# verizon                                      92
# epic_systems                                 91
# zalando                                      90
# booz_allen_hamilton                          90
# hubspot                                      90
# target                                       89
# palo_alto_networks                           89
# netapp                                       87
# docusign                                     86
# groupon                                      86
# slalom                                       85
# wework                                       85
# tableau_software                             84
# mckinsey                                     82
# red_hat                                      81
# mastercard                                   79
# robinhood                                    78
# nike                                         76
# compass                                      76
# kpmg                                         76
# nordstrom                                    75
# synopsys                                     75
# grab                                         74
# slack                                        74
# at&t                                         73
# electronic_arts                              72
# raytheon                                     72
# two_sigma                                    72
# citrix_systems_inc                           72
# barclays                                     70
# palantir                                     70
# hpe                                          70
# mathworks                                    70
# tata_consultancy_services                    69
# wells_fargo                                  69
# blackrock                                    68
# cognizant                                    67
# rubrik                                       66
# okta                                         65
# zendesk                                      65
# bank_of_america                              65
# rally_health                                 65
# capgemini                                    63
# etsy                                         63
# github                                       62
# infosys                                      61
# squarespace                                  60
# bank_of_america_merrill_lynch                60
# roblox                                       59
# juniper_networks                             57
# grubhub                                      57
# mediatek                                     56
# charles_schwab                               56
# hulu                                         55
# roku                                         55
# nokia                                        54
# blizzard_entertainment                       54
# thoughtworks                                 53
# waymo                                        51
# symantec                                     51
# citadel                                      51
# ge_digital                                   50
# fidelity_investments                         49
# zoox                                         49
# datadog                                      48
# credit_karma                                 48
# sofi                                         48
# unity_technologies                           48
# adp                                          47
# publicis_sapient                             47
# akamai                                       47
# shopee                                       47
# cloudera                                     47
# aws                                          46
# the_home_depot                               46
# the_new_york_times_company                   45
# xilinx                                       45
# f5_networks                                  45
# optum                                        45
# western_digital                              45
# wish                                         44
# audible                                      44
# flexport                                     44
# cadence_design_systems                       43
# bcg                                          43
# micron_technology                            43
# argo_ai                                      43
# blue_origin                                  42
# state_farm                                   41
# rivian                                       41
# samsara                                      41
# texas_instruments                            41
# ericsson                                     41
# mozilla                                      41
# redfin                                       41
# bny_mellon                                   40
# tripadvisor                                  40
# chewy                                        40
# pivotal                                      40
# marvell                                      40
# ubs                                          40
# siemens                                      40
# deutsche_bank                                40
# affirm                                       40
# exxonmobil                                   39
# mongodb                                      39
# twitch                                       39
# ey                                           39
# reddit                                       38
# factset                                      38
# klarna                                       38
# bain                                         37
# convoy                                       37
# pure_storage                                 37
# plaid                                        36
# pandora                                      36
# vanguard                                     36
# honeywell                                    36
# asml                                         36
# applied_materials                            35
# rakuten                                      35
# alibaba                                      35
# delivery_hero                                35
# riot_games                                   35
# startup                                      35
# smartsheet                                   34
# chevron                                      33
# ford_motor                                   33
# skyscanner                                   32
# mcafee                                       32
# cloudflare                                   32
# informatica                                  32
# asurion                                      32
# arista_networks                              32
# surveymonkey                                 32
# carta                                        32
# asana                                        32
# l3harris_technologies                        32
# ancestry                                     31
# liberty_mutual                               31
# veritas_technologies                         31
# databricks                                   31
# cox_automotive                               31
# trend_micro                                  30
# gusto                                        30
# paytm                                        30
# zynga                                        30
# sap_concur                                   29
# nextdoor                                     29
# pluralsight                                  29
# coupang                                      29
# rbc                                          28
# ncr                                          28
# thumbtack                                    28
# new_relic                                    28
# stitch_fix                                   28
# zoom                                         28
# starbucks                                    28
# medtronic                                    28
# cohesity                                     27
# lam_research                                 27
# tsmc                                         27
# here_technologies                            27
# fortinet                                     27
# garmin                                       27
# credit_suisse                                27
# sony                                         27
# huawei                                       26
# intel_corporation                            26
# mailchimp                                    26
# amazon_web_services                          26
# gojek_tech                                   26
# glassdoor                                    26
# verily_life_sciences                         26
# hbo                                          26
# chime                                        25
# allstate                                     25
# bcg_digital_ventures                         25
# thought_machine                              25
# avanade                                      25
# crowdstrike                                  24
# 3m                                           24
# supermicro                                   24
# athenahealth                                 24
# postmates                                    24
# yext                                         24
# canva                                        24
# proofpoint                                   24
# veeva_systems                                24
# leidos                                       23
# realtor.com                                  23
# cvs_health                                   23
# american_airlines                            23
# uipath                                       23
# dream11                                      23
# spacex                                       22
# cisco_systems                                22
# zulily                                       22
# intercom                                     22
# kla                                          22
# philips                                      22
# appdynamics                                  22
# rackspace                                    21
# liveramp                                     21
# schlumberger                                 21
# agoda                                        21
# confluent                                    21
# ticketmaster                                 21
# brex                                         21
# fannie_mae                                   21
# better_mortgage                              21
# hashicorp                                    21
# deliveroo                                    21
# illumina                                     20
# northwestern_mutual                          20
# ge                                           20
# peloton                                      20
# digitalocean                                 20
# n26                                          20
# magic_leap                                   20
# automattic                                   20
# macy's                                       20
# snowflake                                    20
# hsbc                                         20
# discover                                     19
# appfolio                                     19
# pnc                                          19
# oath                                         19
# esri                                         19
# swiggy                                       19
# epam                                         19
# cornerstone_ondemand                         19
# ubisoft                                      19
# globallogic                                  19
# cummins                                      19
# revolut                                      19
# tinder                                       18
# vistaprint                                   18
# oscar_health                                 18
# genentech                                    18
# criteo                                       18
# realtek                                      18
# analog_devices                               18
# xandr                                        18
# elastic                                      18
# aetna                                        18
# mapbox                                       18
# sberbank                                     18
# thomson_reuters                              18
# best_buy                                     18
# myntra                                       18
# houzz                                        18
# quora                                        18
# anaplan                                      18
# cimpress                                     17
# amadeus                                      17
# red_ventures                                 17
# coursera                                     17
# viasat                                       17
# axon                                         17
# fitbit                                       17
# nuro                                         17
# jp_morgan_chase                              17
# nerdwallet                                   17
# johnson_&_johnson                            17
# nbcuniversal                                 17
# sprout_social                                17
# tencent                                      17
# careem                                       17
# c3.ai                                        17
# capital_group                                17
# vimeo                                        17
# andela                                       17
# quicken_loans                                17
# draftkings                                   17
# wise                                         17
# mobileiron                                   16
# telus                                        16
# logmein                                      16
# hp                                           16
# lendingclub                                  16
# experian                                     16
# sonos                                        16
# guidewire_software                           16
# nielsen                                      16
# ukg                                          16
# dish_network                                 16
# shutterstock                                 16
# flatiron_health                              16
# procter_&_gamble                             16
# hcl_technologies                             16
# akuna_capital                                16
# cgi_group                                    16
# marqeta                                      16
# lenovo                                       16
# abbott                                       16
# bosch                                        16
# aurora                                       16
# opendoor                                     16
# cadence                                      15
# hp_inc                                       15
# freshworks                                   15
# humana                                       15
# gartner                                      15
# bae_systems                                  15
# prudential_financial                         15
# warnermedia                                  15
# national_instruments                         15
# kroger                                       15
# genesys                                      15
# adyen                                        15
# wepay                                        15
# gitlab                                       14
# discovery                                    14
# zillow_group                                 14
# razorpay                                     14
# playstation                                  14
# cisco_meraki                                 14
# just_eat                                     14
# oyo                                          14
# opentext                                     14
# chan_zuckerberg_initiative                   14
# lowe's                                       14
# zs                                           14
# wipro_limited                                14
# tcs                                          14
# offerup                                      14
# bluecore                                     14
# ihs_markit                                   14
# nxp_semiconductors                           14
# iqvia                                        13
# netskope                                     13
# bosch_global                                 13
# softserve                                    13
# perficient                                   13
# retailmenot                                  13
# deloitte_advisory                            13
# icims                                        13
# asus                                         13
# globant                                      13
# mural                                        13
# zoho                                         13
# nortonlifelock                               13
# soundcloud                                   13
# dolby_laboratories                           13
# tiktok                                       13
# fireeye                                      13
# chegg                                        13
# optimizely                                   13
# commvault                                    13
# tanium                                       13
# weave                                        13
# moody's                                      13
# daimler                                      13
# massmutual                                   13
# mitre                                        13
# general_atomics                              13
# procore_technologies                         13
# carvana                                      13
# blend                                        13
# roche                                        13
# luxoft                                       13
# ge_healthcare                                12
# dxc_technology                               12
# blue_yonder                                  12
# pepsico                                      12
# hewlett_packard_enterprise                   12
# procore                                      12
# boston_consulting_group                      12
# teradata                                     12
# mixpanel                                     12
# deloitte_consulting                          12
# coupa_software                               12
# ally                                         12
# sprinklr                                     12
# blackstone                                   12
# loblaw_digital                               12
# raytheon_technologies                        12
# zs_associates                                12
# rent_the_runway                              12
# maxar_technologies                           12
# world_wide_technology                        12
# saic                                         12
# oscar                                        12
# equifax                                      12
# udemy                                        12
# microchip                                    12
# rippling                                     12
# silicon_valley_bank                          12
# cigna                                        12
# microstrategy                                12
# fis                                          12
# inmobi                                       12
# aptiv                                        12
# ciena                                        12
# auth0                                        12
# clever                                       12
# oliver_wyman                                 12
# fico                                         12
# bose                                         11
# viacomcbs                                    11
# t._rowe_price                                11
# keeptruckin                                  11
# fedex                                        11
# sumo_logic                                   11
# tenable                                      11
# optiver                                      11
# the_trade_desk                               11
# arcesium                                     11
# niantic                                      11
# improbable                                   11
# microsoft_corporation                        11
# bayer                                        11
# nasa_jpl                                     11
# ansys                                        11
# cvent                                        11
# ciklum                                       11
# datarobot                                    11
# mail.ru_group                                11
# micro_focus                                  11
# ringcentral                                  11
# poshmark                                     11
# cgi                                          11
# scotiabank                                   11
# keysight                                     11
# johnson_and_johnson                          11
# mckesson                                     11
# airtable                                     11
# anduril_industries                           11
# mindtree                                     11
# makemytrip                                   11
# amdocs                                       11
# scale_ai                                     11
# hudson_river_trading                         11
# nasdaq                                       11
# smartthings                                  11
# collins_aerospace                            11
# charter_communications                       11
# betterment                                   11
# rapid7                                       10
# elsevier                                     10
# american_family_insurance                    10
# hootsuite                                    10
# sophos                                       10
# zoominfo                                     10
# quantcast                                    10
# g-research                                   10
# the_hartford                                 10
# bloomberg_lp                                 10
# fiserv                                       10
# shipt                                        10
# thermo_fisher_scientific                     10
# gap                                          10
# morningstar                                  10
# hitachi                                      10
# tesco                                        10
# costar_group                                 10
# verizon_media                                10
# wipro                                        10
# paycom                                       10
# the_walt_disney_company                      10
# lucid_motors                                 10
# alarm.com                                    10
# logitech                                     10
# mphasis                                      10
# nice                                         10
# shutterfly                                   10
# wix                                          10
# jpmorgan                                     10
# addepar                                      10
# s&p_global                                   10
# united_airlines                              10
# cloudkitchens                                10
# dell                                         10
# tusimple                                     10
# bandwidth                                    10
# appian                                       10
# glovo                                        10
# samsung_research_america                     10
# synology                                     10
# sas_software                                 10
# booking                                      10
# apple_inc.                                   10
# spectrum                                     10
# constant_contact                             10
# teladoc_health                                9
# wealthfront                                   9
# wolters_kluwer                                9
# mic                                           9
# apptio                                        9
# td_bank                                       9
# the_d._e._shaw_group                          9
# toast                                         9
# the_climate_corporation                       9
# general_electric                              9
# volkswagen                                    9
# pagerduty                                     9
# gopuff                                        9
# intuitive                                     9
# bnp_paribas                                   9
# transunion                                    9
# rbs                                           9
# remitly                                       9
# tower_research_capital                        9
# irobot                                        9
# ford                                          9
# babylon_health                                9
# kaiser_permanente                             9
# ama                                           9
# better.com                                    9
# samsung_electronics_america                   9
# lumen                                         9
# mercer                                        9
# jane_street                                   9
# relativity                                    9
# cdk_global                                    9
# manulife                                      9
# motional                                      9
# mentor_graphics                               9
# bolt                                          9
# geico                                         9
# global_payments                               9
# zocdoc                                        9
# docker                                        9
# dataart                                       9
# cambia_health_solutions                       9
# infor                                         9
# scribd                                        9
# patreon                                       9
# turo                                          9
# john_deere                                    9
# grofers                                       8
# aig                                           8
# thoughtspot                                   8
# amobee                                        8
# chase                                         8
# swisscom                                      8
# mckinsey_&_company                            8
# state_street                                  8
# evernote                                      8
# bolt_(eu)                                     8
# at_kearney                                    8
# kayak                                         8
# societe_generale                              8
# unitedhealth_group                            8
# cargurus                                      8
# virtusa                                       8
# figma                                         8
# epsilon                                       8
# hellofresh                                    8
# equinix                                       8
# playvs                                        8
# disney_streaming_services                     8
# nuance_communications                         8
# verkada                                       8
# cirrus_logic                                  8
# fetch_rewards                                 8
# schneider_electric                            8
# pearson                                       8
# internet_brands                               8
# southwest_airlines                            8
# canonical                                     8
# costco_wholesale                              8
# paylocity                                     8
# overstock                                     8
# micron                                        8
# ripple                                        8
# l3harris                                      8
# traveloka                                     8
# faire                                         8
# ixl_learning                                  8
# fujitsu                                       8
# zscaler                                       8
# zappos                                        8
# intercontinental_exchange                     8
# interactive_brokers                           8
# jp_morgan                                     8
# activecampaign                                8
# olo                                           8
# discord                                       8
# kohl's                                        8
# xero                                          8
# amazon.com                                    8
# ntt_data                                      8
# match                                         8
# igt                                           8
# ellie_mae                                     8
# seagate                                       8
# dialpad                                       8
# beyond_limits                                 8
# blackberry                                    8
# upstart                                       8
# move                                          8
# nubank                                        8
# attentive                                     8
# clearwater_analytics                          8
# expedia_group                                 8
# priceline                                     8
# wp_engine                                     8
# guardant_health                               8
# cibc                                          8
# zapier                                        8
# guidehouse                                    8
# resmed                                        8
# microchip_technology                          8
# amplitude                                     8
# fanduel                                       8
# siriusxm                                      8
# align_technology                              8
# eventbrite                                    8
# iheartradio                                   7
# coupa                                         7
# mutual_of_omaha                               7
# mi                                            7
# travelers                                     7
# udaan.com                                     7
# qualia                                        7
# course_hero                                   7
# mufg                                          7
# silicon_labs                                  7
# flexe                                         7
# jane_street_capital                           7
# zenefits                                      7
# continental                                   7
# servicetitan                                  7
# tokopedia                                     7
# moody's_analytics                             7
# conduent                                      7
# novetta                                       7
# under_armour                                  7
# opentable                                     7
# ocado_technology                              7
# benchling                                     7
# actioniq                                      7
# renesas_electronics                           7
# bill.com                                      7
# gojek                                         7
# ptc                                           7
# motorola                                      7
# ceridian                                      7
# strategy_by_pwc                               7
# deloitte_consulting_llp                       7
# 23andme                                       7
# aruba_networks                                7
# appier                                        7
# 8x8                                           7
# lucid_software                                7
# indigo                                        7
# caci_international                            7
# segment                                       7
# first_republic_bank                           7
# citibank                                      7
# bird                                          7
# imc                                           7
# juul_labs                                     7
# xpo_logistics                                 7
# lek                                           7
# freddie_mac                                   7
# metromile                                     7
# panasonic                                     7
# ivanti                                        7
# illumio                                       7
# manhattan_associates                          7
# nextera_analytics                             7
# clari                                         7
# on_semiconductor                              7
# blink_health                                  7
# vonage                                        7
# fastly                                        7
# adevinta                                      7
# abb                                           7
# applovin                                      7
# leantaas                                      7
# covermymeds                                   7
# contentful                                    7
# domo                                          7
# invision                                      7
# susquehanna_international_group               7
# degreed                                       7
# parsons                                       7
# ultimate_software                             7
# lumentum                                      7
# guidewire                                     7
# visa_inc                                      7
# toyota_usa                                    7
# lendingtree                                   7
# activision                                    7
# point72                                       7
# hopper                                        7
# fifth_third_bank                              7
# commscope                                     7
# liveperson                                    7
# ibotta                                        7
# 2u                                            7
# dexcom                                        7
# sabre                                         7
# acorns                                        7
# merck                                         7
# other                                         7
# u.s._bank                                     7
# msft                                          7
# phonepe                                       7
# office_depot                                  7
# synaptics                                     7
# mitchell_international                        7
# squarepoint_capital                           7
# gocardless                                    7
# epic_games                                    7
# capsule                                       7
# nintendo                                      7
# browserstack                                  7
# foursquare                                    7
# blackbaud                                     7
# duolingo                                      7
# cbre                                          7
# trimble                                       7
# xendit                                        7
# webflow                                       7
# afterpay                                      7
# vrbo                                          7
# media.net                                     7
# carmax                                        6
# airtel_india                                  6
# monzo                                         6
# ola                                           6
# kraken                                        6
# rescale                                       6
# care.com                                      6
# blockfi                                       6
# snapdocs                                      6
# soroco                                        6
# workhuman                                     6
# verint                                        6
# carrier                                       6
# warby_parker                                  6
# ziprecruiter                                  6
# tekion                                        6
# workiva                                       6
# ca_technologies                               6
# doctolib                                      6
# ironclad                                      6
# johnson                                       6
# fullstory                                     6
# hackerrank                                    6
# wattpad                                       6
# five_rings                                    6
# sailpoint                                     6
# centene                                       6
# mcdonald's                                    6
# 10x_genomics                                  6
# doubleverify                                  6
# policygenius                                  6
# bain_&_company                                6
# ss&c_technologies                             6
# stchealth                                     6
# nylas                                         6
# drw                                           6
# csg                                           6
# amgen                                         6
# egen_solutions                                6
# deliverr                                      6
# sony_interactive_entertainment                6
# pegatron                                      6
# blackhawk_network                             6
# virtu_financial                               6
# checkr                                        6
# talend                                        6
# travelport                                    6
# caci                                          6
# alteryx                                       6
# enova_international                           6
# clearbanc                                     6
# iterable                                      6
# oppo                                          6
# baidu                                         6
# pegasystems                                   6
# weedmaps                                      6
# mediaocean                                    6
# appdirect                                     6
# perspecta                                     6
# khoros                                        6
# sysdig                                        6
# ford_motor_company                            6
# tradeweb                                      6
# h-e-b                                         6
# adidas                                        6
# one_medical                                   6
# loandepot                                     6
# avalara                                       6
# grid_dynamics                                 6
# ge_aviation                                   6
# rover                                         6
# bazaarvoice                                   6
# snapchat                                      6
# aruba                                         6
# tempus                                        6
# solarwinds                                    6
# granular                                      6
# sandia_national_labs                          6
# glu_mobile                                    6
# allianz                                       6
# jump_trading                                  6
# juniper_square                                6
# petuum                                        6
# cbs_interactive                               6
# stubhub                                       6
# sonder                                        6
# anonymous                                     6
# maxim_integrated                              6
# fast_enterprises                              6
# willis_towers_watson                          6
# rappi                                         6
# johnson_controls                              6
# sage                                          6
# neustar                                       6
# quantumblack                                  6
# globalfoundries                               6
# fanatics                                      6
# fubotv                                        6
# tomtom                                        6
# intersystems                                  6
# synchrony                                     6
# edx                                           5
# deutsche_telekom                              5
# equipmentshare                                5
# buildium                                      5
# costco                                        5
# investcloud                                   5
# sift                                          5
# gsk                                           5
# alation                                       5
# ernst_&_young                                 5
# dish                                          5
# edwards_lifesciences                          5
# john_hancock                                  5
# puppet                                        5
# earnest                                       5
# jet_propulsion_laboratory                     5
# truckstop.com                                 5
# barracuda_networks                            5
# sps_commerce                                  5
# toyota_research_institute                     5
# cyngn                                         5
# integral_ad_science                           5
# grammarly                                     5
# endava                                        5
# homeadvisor                                   5
# zomato                                        5
# synechron                                     5
# moveworks                                     5
# alphasights                                   5
# everquote                                     5
# icf                                           5
# dynatrace                                     5
# juniper                                       5
# rentpath                                      5
# cox_enterprises                               5
# hca_healthcare                                5
# instabase                                     5
# mellanox                                      5
# infoblox                                      5
# general_dynamics_information_technology       5
# fractal_analytics                             5
# algolia                                       5
# astrazeneca                                   5
# tibco_software                                5
# meesho                                        5
# arista                                        5
# nxp                                           5
# whoop                                         5
# nuance                                        5
# zebra_technologies                            5
# ubiquiti                                      5
# bukalapak                                     5
# macy's,                                       5
# dazn_group                                    5
# pdt_partners                                  5
# genpact                                       5
# bridgewater_associates                        5
# jcpenney                                      5
# truecar                                       5
# singlestore                                   5
# sas                                           5
# liberty_mutual_insurance                      5
# feedzai                                       5
# top_hat                                       5
# bankers_healthcare_group                      5
# panasonic_avionics                            5
# general_dynamics_mission_systems              5
# starling_bank                                 5
# kpit                                          5
# general_mills                                 5
# amzon                                         5
# medallia                                      5
# korn_ferry                                    5
# akamai_technologies                           5
# quantiphi                                     5
# didi                                          5
# meijer                                        5
# onetrust                                      5
# medium                                        5
# unisys                                        5
# intuitive_surgical                            5
# blackline                                     5
# clear_street                                  5
# the_voleon_group                              5
# jio                                           5
# headspace                                     5
# cure.fit                                      5
# button                                        5
# xing                                          5
# 7-eleven                                      5
# taskrabbit                                    5
# change.org                                    5
# google_llc                                    5
# postman                                       5
# alaska_airlines                               5
# delta_air_lines                               5
# stack_overflow                                5
# buzzfeed                                      5
# farfetch                                      5
# marketaxess                                   5
# shell                                         5
# bigcommerce                                   5
# acquia                                        5
# root_insurance                                5
# turbonomic                                    5
# pariveda_solutions                            5
# motorola_solutions                            5
# chick-fil-a                                   5
# dow_jones                                     5
# trinet                                        5
# tinkoff                                       5
# quest_diagnostics                             5
# swiss_re                                      5
# gigamon                                       5
# codecademy                                    5
# doximity                                      5
# cabify                                        5
# lowes                                         5
# cme_group                                     5
# circle                                        5
# numerator                                     5
# stockx                                        5
# excella                                       5
# loom                                          5
# dtcc                                          5
# teksystems                                    5
# autonomic                                     5
# tiaa                                          5
# comscore                                      5
# staples                                       5
# danaher                                       5
# unilever                                      5
# albertsons                                    5
# here                                          5
# homeaway                                      5
# qualcomm_inc                                  5
# ey-parthenon                                  5
# sephora                                       5
# e*trade                                       5
# collective_health                             5
# sas_institute                                 5
# tune                                          5
# cognizant_technology_solutions                5
# tyler_technologies                            5
# circleci                                      5
# ping_identity                                 5
# bumble                                        5
# wealthsimple                                  5
# delphix                                       5
# sisense                                       5
# airbus                                        5
# captech                                       5
# latch                                         5
# imanage                                       5
# stryker                                       5
# league                                        5
# tipalti                                       5
# mantech_international                         5
# infosys_ltd                                   5
# dassault_systemes                             5
# infinera                                      5
# principal_financial_group                     5
# test                                          5
# fti_consulting                                5
# drift.com                                     5
# altran                                        5
# clover_health                                 5
# upwork                                        5
# natera                                        5
# gemini                                        5
# couchbase                                     5
# mendix                                        5
# idemia                                        5
# hyperscience                                  5
# robert_half                                   5
# arrival                                       5
# zeta                                          5
# verisign                                      5
# ing                                           5
# cockroach_labs                                5
# klaviyo                                       5
# iherb                                         5
# avaya                                         5
# lti                                           5
# stash                                         5
# kajabi                                        5
# podium                                        5
# discover_financial_services                   5
# messagebird                                   5
# metlife                                       5
# vizio                                         5
# refinitiv                                     5
# nio                                           5
# Name: std_company_name, dtype: int64

# %%
# Encode Company

# OPTION 0: hot encoding and use all columns
# levels_df = levels_df.join(pd.get_dummies(levels_df.std_company_name))

# OPTION 1: Binary Encoding
# Requires to install category_encoders run: pip install category_encoders
# Using Binary Encoding Reference: https://www.analyticsvidhya.com/blog/2020/08/types-of-categorical-data-encoding/

# binary_encoder = ce.BinaryEncoder(cols=['std_company_name'], return_df=True)
# levels_df = binary_encoder.fit_transform(levels_df)

# OPTION 2: Hot encoding the TOP X most frequent companies
company_threshold = 100 # companies with more than X instances
top_companies = levels_df[levels_df['std_company_name'].isin(levels_df['std_company_name'].value_counts()[levels_df['std_company_name'].value_counts() > company_threshold].index)].std_company_name.unique()
top_companies = top_companies.tolist()
# Join top companies
levels_df = levels_df.join(pd.get_dummies(levels_df.std_company_name)[top_companies])

# # Optional
levels_df.drop(['company'], axis=1, inplace=True)

# %%
# TOP COMPANIES
top_companies
# Out:
# ['oracle',
#  'ebay',
#  'amazon',
#  'apple',
#  'microsoft',
#  'salesforce',
#  'facebook',
#  'uber',
#  'google',
#  'netflix',
#  'pinterest',
#  'linkedin',
#  'adobe',
#  'intel',
#  'lyft',
#  'yelp',
#  'airbnb',
#  'sap',
#  'vmware',
#  'twitter',
#  'cisco',
#  'dropbox',
#  'ibm',
#  'walmart_labs',
#  'twilio',
#  'qualcomm',
#  'tesla',
#  'expedia',
#  'yahoo',
#  'intuit',
#  'bloomberg',
#  'yandex',
#  'capital_one',
#  'workday',
#  'splunk',
#  'samsung',
#  'autodesk',
#  'dell_technologies',
#  'box',
#  'booking.com',
#  'paypal',
#  'atlassian',
#  'indeed',
#  'accenture',
#  'nvidia',
#  'snap',
#  'nutanix',
#  'spotify',
#  'zillow',
#  'godaddy',
#  't-mobile',
#  'goldman_sachs',
#  'cruise',
#  'qualtrics',
#  'northrop_grumman',
#  'deloitte',
#  'jpmorgan_chase',
#  'wayfair',
#  'boeing',
#  'ernst_and_young',
#  'comcast',
#  'square',
#  'american_express',
#  'broadcom',
#  'general_motors',
#  'stripe',
#  'servicenow',
#  'visa',
#  'walmart',
#  'epam_systems',
#  'morgan_stanley',
#  'amd',
#  'doordash',
#  'shopify',
#  'instacart',
#  'lockheed_martin',
#  'pwc',
#  'bytedance']

# %%
# OPTIONAL: Dropping values for not relevant/encoded features:
# 'tag', 'otherdetails', 'dmaid', 'rowNumber' -> not relevant or replicable from user inputs

levels_df.drop(['tag', 'otherdetails', 'dmaid', 'rowNumber'], axis=1, inplace=True)

# %%
# Current available columns
print(levels_df.columns.tolist())
# Out:
# ['timestamp', 'level', 'totalyearlycompensation', 'yearsofexperience', 'yearsatcompany', 'basesalary', 'stockgrantvalue', 'bonus', 'Education', 'std_company_name', 'US', 'United Kingdom', 'India', 'Canada', 'San Francisco, CA', 'Seattle, WA', 'Sunnyvale, CA', 'Mountain View, CA', 'Redmond, WA', 'Menlo Park, CA', 'Cupertino, CA', 'New York, NY', 'San Jose, CA', 'Palo Alto, CA', 'Austin, TX', 'Boston, MA', 'Santa Clara, CA', 'Product Manager', 'Software Engineer', 'Software Engineering Manager', 'Data Scientist', 'Solution Architect', 'Technical Program Manager', 'Hardware Engineer', 'Mechanical Engineer', 'oracle', 'ebay', 'amazon', 'apple', 'microsoft', 'salesforce', 'facebook', 'uber', 'google', 'netflix', 'pinterest', 'linkedin', 'adobe', 'intel', 'lyft', 'yelp', 'airbnb', 'sap', 'vmware', 'twitter', 'cisco', 'dropbox', 'ibm', 'walmart_labs', 'twilio', 'qualcomm', 'tesla', 'expedia', 'yahoo', 'intuit', 'bloomberg', 'yandex', 'capital_one', 'workday', 'splunk', 'samsung', 'autodesk', 'dell_technologies', 'box', 'booking.com', 'paypal', 'atlassian', 'indeed', 'accenture', 'nvidia', 'snap', 'nutanix', 'spotify', 'zillow', 'godaddy', 't-mobile', 'goldman_sachs', 'cruise', 'qualtrics', 'northrop_grumman', 'deloitte', 'jpmorgan_chase', 'wayfair', 'boeing', 'ernst_and_young', 'comcast', 'square', 'american_express', 'broadcom', 'general_motors', 'stripe', 'servicenow', 'visa', 'walmart', 'epam_systems', 'morgan_stanley', 'amd', 'doordash', 'shopify', 'instacart', 'lockheed_martin', 'pwc', 'bytedance']

# %% [markdown]
# ## Models

# %%
from sklearn.model_selection import train_test_split

y = levels_df["bonus"]
X = levels_df.drop(["bonus"], axis=1)
X = X.drop(["timestamp"], axis=1)
X = X.drop(["level"], axis=1)
X = X.drop(["std_company_name"], axis=1)
X = X.drop(["totalyearlycompensation"], axis=1)
X = X.drop(["basesalary"], axis=1)
X = X.drop(["stockgrantvalue"], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X.dtypes.size
# Out:
# 106

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression().fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)

from sklearn.metrics import r2_score, mean_squared_error
import math

display(r2_score(y_test, y_pred))
display(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 0.20360390823008534
# 22378.324142084268

# %%
from sklearn.tree import DecisionTreeRegressor 

dt_reg = DecisionTreeRegressor(random_state = 0).fit(X_train, y_train)
y_pred = dt_reg.predict(X_test)

display(r2_score(y_test, y_pred))
display(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# -0.45782923938335407
# 30277.243135603207

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(n_estimators=400, 
    max_depth=5, 
    learning_rate=0.1, 
    min_samples_split=3).fit(X_train, y_train)

y_pred = gbr.predict(X_test)

display(r2_score(y_test, y_pred))
display(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 0.256725982803954
# 21619.093299452223

# %% [markdown]
# ### Model Tuning: Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Tuning tree-based parameters
# param_test1 = {'n_estimators':range(10,200,10)}  # Results: n_estimators:180 , learning_rate: 0.30, r2: 0.2563207196168972
# param_test2 = {'max_depth':range(5,16,2), 'min_samples_split':range(200,1001,200)} # Results: max_depth:11 , min_samples_split: 1000, r2: 0.2524530529272425
# param_test3 = {'min_samples_leaf':range(30,71,10)} # Results: min_samples_leaf: 30, r2: 0.2547157681688149
# param_test4 = {'max_features':range(10,84,5)} # Results: max_features: 10, r2: 0.255086835405512
# param_test5 = {'subsample':[0.6,0.7,0.75,0.8,0.85,0.9]} # Results: subsample: 0.85, r2: 0.2568778862395251


# gsearch = GridSearchCV(estimator = GradientBoostingRegressor(max_depth=5, 
#     learning_rate=0.3, 
#     min_samples_split=400,
#     min_samples_leaf = 50,
#     max_features='sqrt',
#     subsample=0.8), 
# param_grid = param_test1, scoring='r2',n_jobs=4, cv=5)

# gsearch = GridSearchCV(estimator = GradientBoostingRegressor(learning_rate=0.3,
#     n_estimators=180,
#     max_features='sqrt',
#     subsample=0.8,
#     random_state=10), 
# param_grid = param_test2, scoring='r2',n_jobs=4, cv=5)

# gsearch = GridSearchCV(estimator = GradientBoostingRegressor(learning_rate=0.3,
#     n_estimators=180,
#     max_depth = 11,
#     min_samples_split = 1000,
#     max_features='sqrt',
#     subsample=0.8,
#     random_state=10), 
# param_grid = param_test3, scoring='r2',n_jobs=4, cv=5)

# gsearch = GridSearchCV(estimator = GradientBoostingRegressor(learning_rate=0.3,
#     n_estimators=180,
#     max_depth = 11,
#     min_samples_leaf = 30,
#     min_samples_split = 1000,
#     subsample=0.8,
#     random_state=10), 
# param_grid = param_test4, scoring='r2',n_jobs=4, cv=5)

# gsearch = GridSearchCV(estimator = GradientBoostingRegressor(learning_rate=0.3,
#     n_estimators=180,
#     max_depth = 11,
#     min_samples_leaf = 30,
#     max_features = 10,
#     min_samples_split = 1000,
#     random_state=10), 
# param_grid = param_test5, scoring='r2',n_jobs=4, cv=5)

# Try (learning_rate, n_estimators) = (0.15, 360, r2:0.25951149831166287), (0.07,700,r2:) 
gbr_tuned = GradientBoostingRegressor(learning_rate=0.07,
    n_estimators=700,
    max_depth = 11,
    min_samples_leaf = 30,
    max_features = 10,
    min_samples_split = 1000,
    subsample = 0.85,
    random_state=10)

# Fit model
# gsearch.fit(X_train,y_train)
gbr_tuned.fit(X_train,y_train)

# Print best params
# display(gsearch.best_params_, gsearch.best_score_)

# Predict
# y_pred = gsearch.predict(X_test)
y_pred = gbr_tuned.predict(X_test)
display(r2_score(y_test, y_pred))
display(math.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 0.2677537492787293
# 21458.115492768622

# %% [markdown]
# ### Dump models

# %%
from joblib import dump, load

dump(gbr_tuned, 'bonus_gbr_tuned.joblib')

# from google.colab import files
# files.download('stock_gbr_tuned.joblib')
# Out:
# ['bonus_gbr_tuned.joblib']
